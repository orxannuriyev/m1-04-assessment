# %% [markdown]
# # Task 1: Generate the raw dataset using fixed rules

# %%
import numpy as np

seed_value = int("812")
n = 320
rng = np.random.default_rng(seed_value)
tickets = []

for i in range(1, n+1):
    
    ticket_id = f"T{seed_value}-{i:04d}"
    route = ["NYC-LAX", "LHR-JFK", "SFO-SEA", "DXB-SIN", "MAD-ROM"][(i + seed_value) % 5]
    day = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"][(i + seed_value) % 7]    
    days_to_departure = 1 + ((i * 3 + seed_value) % 60)    
    class_value = ["economy", "premium", "business"][(i * 2 + seed_value) % 3]    
    base = 120 + (days_to_departure * -1.5)
    route_adj = [140, 220, 60, 180, 80][(i + seed_value) % 5]
    class_adj = [0, 80, 220][(i * 2 + seed_value) % 3]
    noise = rng.normal(0, 25)
    price_usd = round(base + route_adj + class_adj + noise, 2)
    
    if i % 28 == 0:
        price_usd = ""
    if i % 45 == 0:        
        if price_usd != "":
            price_usd = price_usd * -1
    if i % 37 == 0:
        class_value = class_value.upper()

    tickets.append({
        "ticket_id": ticket_id,
        "route": route,
        "day": day,
        "days_to_departure": days_to_departure,
        "class": class_value,
        "price_usd": price_usd
    })


print("Total records:", len(tickets))
print("First five records:")
tickets[:5]
# Out:
# Total records: 320
# First five records:
# [{'ticket_id': 'T812-0001',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 36,
#   'class': 'premium',
#   'price_usd': 298.26},
#  {'ticket_id': 'T812-0002',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 39,
#   'class': 'economy',
#   'price_usd': 156.11},
#  {'ticket_id': 'T812-0003',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 42,
#   'class': 'business',
#   'price_usd': 429.67},
#  {'ticket_id': 'T812-0004',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 45,
#   'class': 'premium',
#   'price_usd': 413.07},
#  {'ticket_id': 'T812-0005',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 48,
#   'class': 'economy',
#   'price_usd': 117.02}]

# %%
type(tickets[0]['price_usd'])
# Out:
# float

# %% [markdown]
# # Task 2: Validate and clean records with core Python
# Identify invalid records (missing/non-numeric price_usd, or negative prices). Build cleaned_tickets with only valid records and normalized lowercase class.
#
# After cleaning, confirm cleaned count and verify no invalid prices remain. Show two cleaned records.

# %%
cleaned_records = []
invalid_records = []

for r in tickets:
    price = r.get('price_usd')

    if isinstance(price, (int, float)) and price > 0:
        r['class']= r['class'].lower()
        cleaned_records.append(r)        
    else:
        invalid_records.append(r)

# %%
invalid_records
# Out:
# [{'ticket_id': 'T812-0028',
#   'route': 'NYC-LAX',
#   'day': 'Mon',
#   'days_to_departure': 57,
#   'class': 'premium',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0045',
#   'route': 'SFO-SEA',
#   'day': 'Thu',
#   'days_to_departure': 48,
#   'class': 'business',
#   'price_usd': -325.05},
#  {'ticket_id': 'T812-0056',
#   'route': 'DXB-SIN',
#   'day': 'Mon',
#   'days_to_departure': 21,
#   'class': 'economy',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0084',
#   'route': 'LHR-JFK',
#   'day': 'Mon',
#   'days_to_departure': 45,
#   'class': 'business',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0090',
#   'route': 'SFO-SEA',
#   'day': 'Sun',
#   'days_to_departure': 3,
#   'class': 'business',
#   'price_usd': -400.3},
#  {'ticket_id': 'T812-0112',
#   'route': 'MAD-ROM',
#   'day': 'Mon',
#   'days_to_departure': 9,
#   'class': 'premium',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0135',
#   'route': 'SFO-SEA',
#   'day': 'Wed',
#   'days_to_departure': 18,
#   'class': 'business',
#   'price_usd': -379.28},
#  {'ticket_id': 'T812-0140',
#   'route': 'SFO-SEA',
#   'day': 'Mon',
#   'days_to_departure': 33,
#   'class': 'economy',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0168',
#   'route': 'NYC-LAX',
#   'day': 'Mon',
#   'days_to_departure': 57,
#   'class': 'business',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0180',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 33,
#   'class': 'business',
#   'price_usd': -344.95},
#  {'ticket_id': 'T812-0196',
#   'route': 'DXB-SIN',
#   'day': 'Mon',
#   'days_to_departure': 21,
#   'class': 'premium',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0224',
#   'route': 'LHR-JFK',
#   'day': 'Mon',
#   'days_to_departure': 45,
#   'class': 'economy',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0225',
#   'route': 'SFO-SEA',
#   'day': 'Tue',
#   'days_to_departure': 48,
#   'class': 'business',
#   'price_usd': -365.8},
#  {'ticket_id': 'T812-0252',
#   'route': 'MAD-ROM',
#   'day': 'Mon',
#   'days_to_departure': 9,
#   'class': 'business',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0270',
#   'route': 'SFO-SEA',
#   'day': 'Fri',
#   'days_to_departure': 3,
#   'class': 'business',
#   'price_usd': -368.11},
#  {'ticket_id': 'T812-0280',
#   'route': 'SFO-SEA',
#   'day': 'Mon',
#   'days_to_departure': 33,
#   'class': 'premium',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0308',
#   'route': 'NYC-LAX',
#   'day': 'Mon',
#   'days_to_departure': 57,
#   'class': 'economy',
#   'price_usd': ''},
#  {'ticket_id': 'T812-0315',
#   'route': 'SFO-SEA',
#   'day': 'Mon',
#   'days_to_departure': 18,
#   'class': 'business',
#   'price_usd': -369.06}]

# %%
cleaned_records
# Out:
# [{'ticket_id': 'T812-0001',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 36,
#   'class': 'premium',
#   'price_usd': 298.26},
#  {'ticket_id': 'T812-0002',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 39,
#   'class': 'economy',
#   'price_usd': 156.11},
#  {'ticket_id': 'T812-0003',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 42,
#   'class': 'business',
#   'price_usd': 429.67},
#  {'ticket_id': 'T812-0004',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 45,
#   'class': 'premium',
#   'price_usd': 413.07},
#  {'ticket_id': 'T812-0005',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 48,
#   'class': 'economy',
#   'price_usd': 117.02},
#  {'ticket_id': 'T812-0006',
#   'route': 'DXB-SIN',
#   'day': 'Sun',
#   'days_to_departure': 51,
#   'class': 'business',
#   'price_usd': 450.43},
#  {'ticket_id': 'T812-0007',
#   'route': 'MAD-ROM',
#   'day': 'Mon',
#   'days_to_departure': 54,
#   'class': 'premium',
#   'price_usd': 171.18},
#  {'ticket_id': 'T812-0008',
#   'route': 'NYC-LAX',
#   'day': 'Tue',
#   'days_to_departure': 57,
#   'class': 'economy',
#   'price_usd': 145.16},
#  {'ticket_id': 'T812-0009',
#   'route': 'LHR-JFK',
#   'day': 'Wed',
#   'days_to_departure': 60,
#   'class': 'business',
#   'price_usd': 429.25},
#  {'ticket_id': 'T812-0010',
#   'route': 'SFO-SEA',
#   'day': 'Thu',
#   'days_to_departure': 3,
#   'class': 'premium',
#   'price_usd': 315.81},
#  {'ticket_id': 'T812-0011',
#   'route': 'DXB-SIN',
#   'day': 'Fri',
#   'days_to_departure': 6,
#   'class': 'economy',
#   'price_usd': 311.3},
#  {'ticket_id': 'T812-0012',
#   'route': 'MAD-ROM',
#   'day': 'Sat',
#   'days_to_departure': 9,
#   'class': 'business',
#   'price_usd': 407.13},
#  {'ticket_id': 'T812-0013',
#   'route': 'NYC-LAX',
#   'day': 'Sun',
#   'days_to_departure': 12,
#   'class': 'premium',
#   'price_usd': 302.0},
#  {'ticket_id': 'T812-0014',
#   'route': 'LHR-JFK',
#   'day': 'Mon',
#   'days_to_departure': 15,
#   'class': 'economy',
#   'price_usd': 343.47},
#  {'ticket_id': 'T812-0015',
#   'route': 'SFO-SEA',
#   'day': 'Tue',
#   'days_to_departure': 18,
#   'class': 'business',
#   'price_usd': 362.25},
#  {'ticket_id': 'T812-0016',
#   'route': 'DXB-SIN',
#   'day': 'Wed',
#   'days_to_departure': 21,
#   'class': 'premium',
#   'price_usd': 402.66},
#  {'ticket_id': 'T812-0017',
#   'route': 'MAD-ROM',
#   'day': 'Thu',
#   'days_to_departure': 24,
#   'class': 'economy',
#   'price_usd': 146.76},
#  {'ticket_id': 'T812-0018',
#   'route': 'NYC-LAX',
#   'day': 'Fri',
#   'days_to_departure': 27,
#   'class': 'business',
#   'price_usd': 473.9},
#  {'ticket_id': 'T812-0019',
#   'route': 'LHR-JFK',
#   'day': 'Sat',
#   'days_to_departure': 30,
#   'class': 'premium',
#   'price_usd': 427.17},
#  {'ticket_id': 'T812-0020',
#   'route': 'SFO-SEA',
#   'day': 'Sun',
#   'days_to_departure': 33,
#   'class': 'economy',
#   'price_usd': 139.61},
#  {'ticket_id': 'T812-0021',
#   'route': 'DXB-SIN',
#   'day': 'Mon',
#   'days_to_departure': 36,
#   'class': 'business',
#   'price_usd': 471.15},
#  {'ticket_id': 'T812-0022',
#   'route': 'MAD-ROM',
#   'day': 'Tue',
#   'days_to_departure': 39,
#   'class': 'premium',
#   'price_usd': 249.56},
#  {'ticket_id': 'T812-0023',
#   'route': 'NYC-LAX',
#   'day': 'Wed',
#   'days_to_departure': 42,
#   'class': 'economy',
#   'price_usd': 174.63},
#  {'ticket_id': 'T812-0024',
#   'route': 'LHR-JFK',
#   'day': 'Thu',
#   'days_to_departure': 45,
#   'class': 'business',
#   'price_usd': 544.85},
#  {'ticket_id': 'T812-0025',
#   'route': 'SFO-SEA',
#   'day': 'Fri',
#   'days_to_departure': 48,
#   'class': 'premium',
#   'price_usd': 176.67},
#  {'ticket_id': 'T812-0026',
#   'route': 'DXB-SIN',
#   'day': 'Sat',
#   'days_to_departure': 51,
#   'class': 'economy',
#   'price_usd': 216.58},
#  {'ticket_id': 'T812-0027',
#   'route': 'MAD-ROM',
#   'day': 'Sun',
#   'days_to_departure': 54,
#   'class': 'business',
#   'price_usd': 341.88},
#  {'ticket_id': 'T812-0029',
#   'route': 'LHR-JFK',
#   'day': 'Tue',
#   'days_to_departure': 60,
#   'class': 'economy',
#   'price_usd': 310.02},
#  {'ticket_id': 'T812-0030',
#   'route': 'SFO-SEA',
#   'day': 'Wed',
#   'days_to_departure': 3,
#   'class': 'business',
#   'price_usd': 417.53},
#  {'ticket_id': 'T812-0031',
#   'route': 'DXB-SIN',
#   'day': 'Thu',
#   'days_to_departure': 6,
#   'class': 'premium',
#   'price_usd': 348.68},
#  {'ticket_id': 'T812-0032',
#   'route': 'MAD-ROM',
#   'day': 'Fri',
#   'days_to_departure': 9,
#   'class': 'economy',
#   'price_usd': 210.88},
#  {'ticket_id': 'T812-0033',
#   'route': 'NYC-LAX',
#   'day': 'Sat',
#   'days_to_departure': 12,
#   'class': 'business',
#   'price_usd': 491.68},
#  {'ticket_id': 'T812-0034',
#   'route': 'LHR-JFK',
#   'day': 'Sun',
#   'days_to_departure': 15,
#   'class': 'premium',
#   'price_usd': 445.63},
#  {'ticket_id': 'T812-0035',
#   'route': 'SFO-SEA',
#   'day': 'Mon',
#   'days_to_departure': 18,
#   'class': 'economy',
#   'price_usd': 200.72},
#  {'ticket_id': 'T812-0036',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 21,
#   'class': 'business',
#   'price_usd': 472.81},
#  {'ticket_id': 'T812-0037',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 24,
#   'class': 'premium',
#   'price_usd': 220.67},
#  {'ticket_id': 'T812-0038',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 27,
#   'class': 'economy',
#   'price_usd': 236.22},
#  {'ticket_id': 'T812-0039',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 30,
#   'class': 'business',
#   'price_usd': 560.76},
#  {'ticket_id': 'T812-0040',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 33,
#   'class': 'premium',
#   'price_usd': 234.28},
#  {'ticket_id': 'T812-0041',
#   'route': 'DXB-SIN',
#   'day': 'Sun',
#   'days_to_departure': 36,
#   'class': 'economy',
#   'price_usd': 187.23},
#  {'ticket_id': 'T812-0042',
#   'route': 'MAD-ROM',
#   'day': 'Mon',
#   'days_to_departure': 39,
#   'class': 'business',
#   'price_usd': 347.76},
#  {'ticket_id': 'T812-0043',
#   'route': 'NYC-LAX',
#   'day': 'Tue',
#   'days_to_departure': 42,
#   'class': 'premium',
#   'price_usd': 308.51},
#  {'ticket_id': 'T812-0044',
#   'route': 'LHR-JFK',
#   'day': 'Wed',
#   'days_to_departure': 45,
#   'class': 'economy',
#   'price_usd': 263.0},
#  {'ticket_id': 'T812-0046',
#   'route': 'DXB-SIN',
#   'day': 'Fri',
#   'days_to_departure': 51,
#   'class': 'premium',
#   'price_usd': 314.45},
#  {'ticket_id': 'T812-0047',
#   'route': 'MAD-ROM',
#   'day': 'Sat',
#   'days_to_departure': 54,
#   'class': 'economy',
#   'price_usd': 139.73},
#  {'ticket_id': 'T812-0048',
#   'route': 'NYC-LAX',
#   'day': 'Sun',
#   'days_to_departure': 57,
#   'class': 'business',
#   'price_usd': 345.12},
#  {'ticket_id': 'T812-0049',
#   'route': 'LHR-JFK',
#   'day': 'Mon',
#   'days_to_departure': 60,
#   'class': 'premium',
#   'price_usd': 328.21},
#  {'ticket_id': 'T812-0050',
#   'route': 'SFO-SEA',
#   'day': 'Tue',
#   'days_to_departure': 3,
#   'class': 'economy',
#   'price_usd': 178.7},
#  {'ticket_id': 'T812-0051',
#   'route': 'DXB-SIN',
#   'day': 'Wed',
#   'days_to_departure': 6,
#   'class': 'business',
#   'price_usd': 482.02},
#  {'ticket_id': 'T812-0052',
#   'route': 'MAD-ROM',
#   'day': 'Thu',
#   'days_to_departure': 9,
#   'class': 'premium',
#   'price_usd': 238.95},
#  {'ticket_id': 'T812-0053',
#   'route': 'NYC-LAX',
#   'day': 'Fri',
#   'days_to_departure': 12,
#   'class': 'economy',
#   'price_usd': 204.02},
#  {'ticket_id': 'T812-0054',
#   'route': 'LHR-JFK',
#   'day': 'Sat',
#   'days_to_departure': 15,
#   'class': 'business',
#   'price_usd': 556.98},
#  {'ticket_id': 'T812-0055',
#   'route': 'SFO-SEA',
#   'day': 'Sun',
#   'days_to_departure': 18,
#   'class': 'premium',
#   'price_usd': 264.94},
#  {'ticket_id': 'T812-0057',
#   'route': 'MAD-ROM',
#   'day': 'Tue',
#   'days_to_departure': 24,
#   'class': 'business',
#   'price_usd': 366.37},
#  {'ticket_id': 'T812-0058',
#   'route': 'NYC-LAX',
#   'day': 'Wed',
#   'days_to_departure': 27,
#   'class': 'premium',
#   'price_usd': 314.7},
#  {'ticket_id': 'T812-0059',
#   'route': 'LHR-JFK',
#   'day': 'Thu',
#   'days_to_departure': 30,
#   'class': 'economy',
#   'price_usd': 292.71},
#  {'ticket_id': 'T812-0060',
#   'route': 'SFO-SEA',
#   'day': 'Fri',
#   'days_to_departure': 33,
#   'class': 'business',
#   'price_usd': 324.5},
#  {'ticket_id': 'T812-0061',
#   'route': 'DXB-SIN',
#   'day': 'Sat',
#   'days_to_departure': 36,
#   'class': 'premium',
#   'price_usd': 355.56},
#  {'ticket_id': 'T812-0062',
#   'route': 'MAD-ROM',
#   'day': 'Sun',
#   'days_to_departure': 39,
#   'class': 'economy',
#   'price_usd': 180.93},
#  {'ticket_id': 'T812-0063',
#   'route': 'NYC-LAX',
#   'day': 'Mon',
#   'days_to_departure': 42,
#   'class': 'business',
#   'price_usd': 378.26},
#  {'ticket_id': 'T812-0064',
#   'route': 'LHR-JFK',
#   'day': 'Tue',
#   'days_to_departure': 45,
#   'class': 'premium',
#   'price_usd': 395.66},
#  {'ticket_id': 'T812-0065',
#   'route': 'SFO-SEA',
#   'day': 'Wed',
#   'days_to_departure': 48,
#   'class': 'economy',
#   'price_usd': 85.41},
#  {'ticket_id': 'T812-0066',
#   'route': 'DXB-SIN',
#   'day': 'Thu',
#   'days_to_departure': 51,
#   'class': 'business',
#   'price_usd': 431.78},
#  {'ticket_id': 'T812-0067',
#   'route': 'MAD-ROM',
#   'day': 'Fri',
#   'days_to_departure': 54,
#   'class': 'premium',
#   'price_usd': 229.97},
#  {'ticket_id': 'T812-0068',
#   'route': 'NYC-LAX',
#   'day': 'Sat',
#   'days_to_departure': 57,
#   'class': 'economy',
#   'price_usd': 186.61},
#  {'ticket_id': 'T812-0069',
#   'route': 'LHR-JFK',
#   'day': 'Sun',
#   'days_to_departure': 60,
#   'class': 'business',
#   'price_usd': 432.11},
#  {'ticket_id': 'T812-0070',
#   'route': 'SFO-SEA',
#   'day': 'Mon',
#   'days_to_departure': 3,
#   'class': 'premium',
#   'price_usd': 223.6},
#  {'ticket_id': 'T812-0071',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 6,
#   'class': 'economy',
#   'price_usd': 312.27},
#  {'ticket_id': 'T812-0072',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 9,
#   'class': 'business',
#   'price_usd': 446.5},
#  {'ticket_id': 'T812-0073',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 12,
#   'class': 'premium',
#   'price_usd': 300.48},
#  {'ticket_id': 'T812-0074',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 15,
#   'class': 'economy',
#   'price_usd': 364.66},
#  {'ticket_id': 'T812-0075',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 18,
#   'class': 'business',
#   'price_usd': 362.79},
#  {'ticket_id': 'T812-0076',
#   'route': 'DXB-SIN',
#   'day': 'Sun',
#   'days_to_departure': 21,
#   'class': 'premium',
#   'price_usd': 343.44},
#  {'ticket_id': 'T812-0077',
#   'route': 'MAD-ROM',
#   'day': 'Mon',
#   'days_to_departure': 24,
#   'class': 'economy',
#   'price_usd': 186.01},
#  {'ticket_id': 'T812-0078',
#   'route': 'NYC-LAX',
#   'day': 'Tue',
#   'days_to_departure': 27,
#   'class': 'business',
#   'price_usd': 430.29},
#  {'ticket_id': 'T812-0079',
#   'route': 'LHR-JFK',
#   'day': 'Wed',
#   'days_to_departure': 30,
#   'class': 'premium',
#   'price_usd': 386.03},
#  {'ticket_id': 'T812-0080',
#   'route': 'SFO-SEA',
#   'day': 'Thu',
#   'days_to_departure': 33,
#   'class': 'economy',
#   'price_usd': 136.61},
#  {'ticket_id': 'T812-0081',
#   'route': 'DXB-SIN',
#   'day': 'Fri',
#   'days_to_departure': 36,
#   'class': 'business',
#   'price_usd': 500.18},
#  {'ticket_id': 'T812-0082',
#   'route': 'MAD-ROM',
#   'day': 'Sat',
#   'days_to_departure': 39,
#   'class': 'premium',
#   'price_usd': 211.57},
#  {'ticket_id': 'T812-0083',
#   'route': 'NYC-LAX',
#   'day': 'Sun',
#   'days_to_departure': 42,
#   'class': 'economy',
#   'price_usd': 218.34},
#  {'ticket_id': 'T812-0085',
#   'route': 'SFO-SEA',
#   'day': 'Tue',
#   'days_to_departure': 48,
#   'class': 'premium',
#   'price_usd': 211.49},
#  {'ticket_id': 'T812-0086',
#   'route': 'DXB-SIN',
#   'day': 'Wed',
#   'days_to_departure': 51,
#   'class': 'economy',
#   'price_usd': 227.44},
#  {'ticket_id': 'T812-0087',
#   'route': 'MAD-ROM',
#   'day': 'Thu',
#   'days_to_departure': 54,
#   'class': 'business',
#   'price_usd': 387.08},
#  {'ticket_id': 'T812-0088',
#   'route': 'NYC-LAX',
#   'day': 'Fri',
#   'days_to_departure': 57,
#   'class': 'premium',
#   'price_usd': 249.66},
#  {'ticket_id': 'T812-0089',
#   'route': 'LHR-JFK',
#   'day': 'Sat',
#   'days_to_departure': 60,
#   'class': 'economy',
#   'price_usd': 220.19},
#  {'ticket_id': 'T812-0091',
#   'route': 'DXB-SIN',
#   'day': 'Mon',
#   'days_to_departure': 6,
#   'class': 'premium',
#   'price_usd': 335.26},
#  {'ticket_id': 'T812-0092',
#   'route': 'MAD-ROM',
#   'day': 'Tue',
#   'days_to_departure': 9,
#   'class': 'economy',
#   'price_usd': 189.26},
#  {'ticket_id': 'T812-0093',
#   'route': 'NYC-LAX',
#   'day': 'Wed',
#   'days_to_departure': 12,
#   'class': 'business',
#   'price_usd': 490.77},
#  {'ticket_id': 'T812-0094',
#   'route': 'LHR-JFK',
#   'day': 'Thu',
#   'days_to_departure': 15,
#   'class': 'premium',
#   'price_usd': 382.06},
#  {'ticket_id': 'T812-0095',
#   'route': 'SFO-SEA',
#   'day': 'Fri',
#   'days_to_departure': 18,
#   'class': 'economy',
#   'price_usd': 126.82},
#  {'ticket_id': 'T812-0096',
#   'route': 'DXB-SIN',
#   'day': 'Sat',
#   'days_to_departure': 21,
#   'class': 'business',
#   'price_usd': 456.71},
#  {'ticket_id': 'T812-0097',
#   'route': 'MAD-ROM',
#   'day': 'Sun',
#   'days_to_departure': 24,
#   'class': 'premium',
#   'price_usd': 224.68},
#  {'ticket_id': 'T812-0098',
#   'route': 'NYC-LAX',
#   'day': 'Mon',
#   'days_to_departure': 27,
#   'class': 'economy',
#   'price_usd': 226.47},
#  {'ticket_id': 'T812-0099',
#   'route': 'LHR-JFK',
#   'day': 'Tue',
#   'days_to_departure': 30,
#   'class': 'business',
#   'price_usd': 518.32},
#  {'ticket_id': 'T812-0100',
#   'route': 'SFO-SEA',
#   'day': 'Wed',
#   'days_to_departure': 33,
#   'class': 'premium',
#   'price_usd': 194.72},
#  {'ticket_id': 'T812-0101',
#   'route': 'DXB-SIN',
#   'day': 'Thu',
#   'days_to_departure': 36,
#   'class': 'economy',
#   'price_usd': 230.49},
#  {'ticket_id': 'T812-0102',
#   'route': 'MAD-ROM',
#   'day': 'Fri',
#   'days_to_departure': 39,
#   'class': 'business',
#   'price_usd': 341.42},
#  {'ticket_id': 'T812-0103',
#   'route': 'NYC-LAX',
#   'day': 'Sat',
#   'days_to_departure': 42,
#   'class': 'premium',
#   'price_usd': 294.66},
#  {'ticket_id': 'T812-0104',
#   'route': 'LHR-JFK',
#   'day': 'Sun',
#   'days_to_departure': 45,
#   'class': 'economy',
#   'price_usd': 255.72},
#  {'ticket_id': 'T812-0105',
#   'route': 'SFO-SEA',
#   'day': 'Mon',
#   'days_to_departure': 48,
#   'class': 'business',
#   'price_usd': 332.85},
#  {'ticket_id': 'T812-0106',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 51,
#   'class': 'premium',
#   'price_usd': 289.82},
#  {'ticket_id': 'T812-0107',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 54,
#   'class': 'economy',
#   'price_usd': 109.89},
#  {'ticket_id': 'T812-0108',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 57,
#   'class': 'business',
#   'price_usd': 388.8},
#  {'ticket_id': 'T812-0109',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 60,
#   'class': 'premium',
#   'price_usd': 358.67},
#  {'ticket_id': 'T812-0110',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 3,
#   'class': 'economy',
#   'price_usd': 173.62},
#  {'ticket_id': 'T812-0111',
#   'route': 'DXB-SIN',
#   'day': 'Sun',
#   'days_to_departure': 6,
#   'class': 'business',
#   'price_usd': 459.7},
#  {'ticket_id': 'T812-0113',
#   'route': 'NYC-LAX',
#   'day': 'Tue',
#   'days_to_departure': 12,
#   'class': 'economy',
#   'price_usd': 223.68},
#  {'ticket_id': 'T812-0114',
#   'route': 'LHR-JFK',
#   'day': 'Wed',
#   'days_to_departure': 15,
#   'class': 'business',
#   'price_usd': 518.5},
#  {'ticket_id': 'T812-0115',
#   'route': 'SFO-SEA',
#   'day': 'Thu',
#   'days_to_departure': 18,
#   'class': 'premium',
#   'price_usd': 254.44},
#  {'ticket_id': 'T812-0116',
#   'route': 'DXB-SIN',
#   'day': 'Fri',
#   'days_to_departure': 21,
#   'class': 'economy',
#   'price_usd': 290.17},
#  {'ticket_id': 'T812-0117',
#   'route': 'MAD-ROM',
#   'day': 'Sat',
#   'days_to_departure': 24,
#   'class': 'business',
#   'price_usd': 371.21},
#  {'ticket_id': 'T812-0118',
#   'route': 'NYC-LAX',
#   'day': 'Sun',
#   'days_to_departure': 27,
#   'class': 'premium',
#   'price_usd': 266.67},
#  {'ticket_id': 'T812-0119',
#   'route': 'LHR-JFK',
#   'day': 'Mon',
#   'days_to_departure': 30,
#   'class': 'economy',
#   'price_usd': 278.07},
#  {'ticket_id': 'T812-0120',
#   'route': 'SFO-SEA',
#   'day': 'Tue',
#   'days_to_departure': 33,
#   'class': 'business',
#   'price_usd': 356.17},
#  {'ticket_id': 'T812-0121',
#   'route': 'DXB-SIN',
#   'day': 'Wed',
#   'days_to_departure': 36,
#   'class': 'premium',
#   'price_usd': 318.81},
#  {'ticket_id': 'T812-0122',
#   'route': 'MAD-ROM',
#   'day': 'Thu',
#   'days_to_departure': 39,
#   'class': 'economy',
#   'price_usd': 137.98},
#  {'ticket_id': 'T812-0123',
#   'route': 'NYC-LAX',
#   'day': 'Fri',
#   'days_to_departure': 42,
#   'class': 'business',
#   'price_usd': 406.24},
#  {'ticket_id': 'T812-0124',
#   'route': 'LHR-JFK',
#   'day': 'Sat',
#   'days_to_departure': 45,
#   'class': 'premium',
#   'price_usd': 359.92},
#  {'ticket_id': 'T812-0125',
#   'route': 'SFO-SEA',
#   'day': 'Sun',
#   'days_to_departure': 48,
#   'class': 'economy',
#   'price_usd': 118.44},
#  {'ticket_id': 'T812-0126',
#   'route': 'DXB-SIN',
#   'day': 'Mon',
#   'days_to_departure': 51,
#   'class': 'business',
#   'price_usd': 396.23},
#  {'ticket_id': 'T812-0127',
#   'route': 'MAD-ROM',
#   'day': 'Tue',
#   'days_to_departure': 54,
#   'class': 'premium',
#   'price_usd': 209.23},
#  {'ticket_id': 'T812-0128',
#   'route': 'NYC-LAX',
#   'day': 'Wed',
#   'days_to_departure': 57,
#   'class': 'economy',
#   'price_usd': 199.12},
#  {'ticket_id': 'T812-0129',
#   'route': 'LHR-JFK',
#   'day': 'Thu',
#   'days_to_departure': 60,
#   'class': 'business',
#   'price_usd': 474.04},
#  {'ticket_id': 'T812-0130',
#   'route': 'SFO-SEA',
#   'day': 'Fri',
#   'days_to_departure': 3,
#   'class': 'premium',
#   'price_usd': 250.76},
#  {'ticket_id': 'T812-0131',
#   'route': 'DXB-SIN',
#   'day': 'Sat',
#   'days_to_departure': 6,
#   'class': 'economy',
#   'price_usd': 282.03},
#  {'ticket_id': 'T812-0132',
#   'route': 'MAD-ROM',
#   'day': 'Sun',
#   'days_to_departure': 9,
#   'class': 'business',
#   'price_usd': 402.52},
#  {'ticket_id': 'T812-0133',
#   'route': 'NYC-LAX',
#   'day': 'Mon',
#   'days_to_departure': 12,
#   'class': 'premium',
#   'price_usd': 365.67},
#  {'ticket_id': 'T812-0134',
#   'route': 'LHR-JFK',
#   'day': 'Tue',
#   'days_to_departure': 15,
#   'class': 'economy',
#   'price_usd': 289.61},
#  {'ticket_id': 'T812-0136',
#   'route': 'DXB-SIN',
#   'day': 'Thu',
#   'days_to_departure': 21,
#   'class': 'premium',
#   'price_usd': 381.52},
#  {'ticket_id': 'T812-0137',
#   'route': 'MAD-ROM',
#   'day': 'Fri',
#   'days_to_departure': 24,
#   'class': 'economy',
#   'price_usd': 189.31},
#  {'ticket_id': 'T812-0138',
#   'route': 'NYC-LAX',
#   'day': 'Sat',
#   'days_to_departure': 27,
#   'class': 'business',
#   'price_usd': 428.25},
#  {'ticket_id': 'T812-0139',
#   'route': 'LHR-JFK',
#   'day': 'Sun',
#   'days_to_departure': 30,
#   'class': 'premium',
#   'price_usd': 312.07},
#  {'ticket_id': 'T812-0141',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 36,
#   'class': 'business',
#   'price_usd': 451.96},
#  {'ticket_id': 'T812-0142',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 39,
#   'class': 'premium',
#   'price_usd': 249.76},
#  {'ticket_id': 'T812-0143',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 42,
#   'class': 'economy',
#   'price_usd': 191.29},
#  {'ticket_id': 'T812-0144',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 45,
#   'class': 'business',
#   'price_usd': 522.45},
#  {'ticket_id': 'T812-0145',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 48,
#   'class': 'premium',
#   'price_usd': 210.01},
#  {'ticket_id': 'T812-0146',
#   'route': 'DXB-SIN',
#   'day': 'Sun',
#   'days_to_departure': 51,
#   'class': 'economy',
#   'price_usd': 237.49},
#  {'ticket_id': 'T812-0147',
#   'route': 'MAD-ROM',
#   'day': 'Mon',
#   'days_to_departure': 54,
#   'class': 'business',
#   'price_usd': 315.87},
#  {'ticket_id': 'T812-0148',
#   'route': 'NYC-LAX',
#   'day': 'Tue',
#   'days_to_departure': 57,
#   'class': 'premium',
#   'price_usd': 288.89},
#  {'ticket_id': 'T812-0149',
#   'route': 'LHR-JFK',
#   'day': 'Wed',
#   'days_to_departure': 60,
#   'class': 'economy',
#   'price_usd': 236.21},
#  {'ticket_id': 'T812-0150',
#   'route': 'SFO-SEA',
#   'day': 'Thu',
#   'days_to_departure': 3,
#   'class': 'business',
#   'price_usd': 396.09},
#  {'ticket_id': 'T812-0151',
#   'route': 'DXB-SIN',
#   'day': 'Fri',
#   'days_to_departure': 6,
#   'class': 'premium',
#   'price_usd': 381.55},
#  {'ticket_id': 'T812-0152',
#   'route': 'MAD-ROM',
#   'day': 'Sat',
#   'days_to_departure': 9,
#   'class': 'economy',
#   'price_usd': 158.38},
#  {'ticket_id': 'T812-0153',
#   'route': 'NYC-LAX',
#   'day': 'Sun',
#   'days_to_departure': 12,
#   'class': 'business',
#   'price_usd': 495.17},
#  {'ticket_id': 'T812-0154',
#   'route': 'LHR-JFK',
#   'day': 'Mon',
#   'days_to_departure': 15,
#   'class': 'premium',
#   'price_usd': 382.47},
#  {'ticket_id': 'T812-0155',
#   'route': 'SFO-SEA',
#   'day': 'Tue',
#   'days_to_departure': 18,
#   'class': 'economy',
#   'price_usd': 121.11},
#  {'ticket_id': 'T812-0156',
#   'route': 'DXB-SIN',
#   'day': 'Wed',
#   'days_to_departure': 21,
#   'class': 'business',
#   'price_usd': 493.94},
#  {'ticket_id': 'T812-0157',
#   'route': 'MAD-ROM',
#   'day': 'Thu',
#   'days_to_departure': 24,
#   'class': 'premium',
#   'price_usd': 245.56},
#  {'ticket_id': 'T812-0158',
#   'route': 'NYC-LAX',
#   'day': 'Fri',
#   'days_to_departure': 27,
#   'class': 'economy',
#   'price_usd': 241.92},
#  {'ticket_id': 'T812-0159',
#   'route': 'LHR-JFK',
#   'day': 'Sat',
#   'days_to_departure': 30,
#   'class': 'business',
#   'price_usd': 437.3},
#  {'ticket_id': 'T812-0160',
#   'route': 'SFO-SEA',
#   'day': 'Sun',
#   'days_to_departure': 33,
#   'class': 'premium',
#   'price_usd': 192.43},
#  {'ticket_id': 'T812-0161',
#   'route': 'DXB-SIN',
#   'day': 'Mon',
#   'days_to_departure': 36,
#   'class': 'economy',
#   'price_usd': 267.73},
#  {'ticket_id': 'T812-0162',
#   'route': 'MAD-ROM',
#   'day': 'Tue',
#   'days_to_departure': 39,
#   'class': 'business',
#   'price_usd': 365.49},
#  {'ticket_id': 'T812-0163',
#   'route': 'NYC-LAX',
#   'day': 'Wed',
#   'days_to_departure': 42,
#   'class': 'premium',
#   'price_usd': 292.9},
#  {'ticket_id': 'T812-0164',
#   'route': 'LHR-JFK',
#   'day': 'Thu',
#   'days_to_departure': 45,
#   'class': 'economy',
#   'price_usd': 264.66},
#  {'ticket_id': 'T812-0165',
#   'route': 'SFO-SEA',
#   'day': 'Fri',
#   'days_to_departure': 48,
#   'class': 'business',
#   'price_usd': 347.98},
#  {'ticket_id': 'T812-0166',
#   'route': 'DXB-SIN',
#   'day': 'Sat',
#   'days_to_departure': 51,
#   'class': 'premium',
#   'price_usd': 257.28},
#  {'ticket_id': 'T812-0167',
#   'route': 'MAD-ROM',
#   'day': 'Sun',
#   'days_to_departure': 54,
#   'class': 'economy',
#   'price_usd': 97.02},
#  {'ticket_id': 'T812-0169',
#   'route': 'LHR-JFK',
#   'day': 'Tue',
#   'days_to_departure': 60,
#   'class': 'premium',
#   'price_usd': 358.17},
#  {'ticket_id': 'T812-0170',
#   'route': 'SFO-SEA',
#   'day': 'Wed',
#   'days_to_departure': 3,
#   'class': 'economy',
#   'price_usd': 187.34},
#  {'ticket_id': 'T812-0171',
#   'route': 'DXB-SIN',
#   'day': 'Thu',
#   'days_to_departure': 6,
#   'class': 'business',
#   'price_usd': 540.53},
#  {'ticket_id': 'T812-0172',
#   'route': 'MAD-ROM',
#   'day': 'Fri',
#   'days_to_departure': 9,
#   'class': 'premium',
#   'price_usd': 275.26},
#  {'ticket_id': 'T812-0173',
#   'route': 'NYC-LAX',
#   'day': 'Sat',
#   'days_to_departure': 12,
#   'class': 'economy',
#   'price_usd': 227.97},
#  {'ticket_id': 'T812-0174',
#   'route': 'LHR-JFK',
#   'day': 'Sun',
#   'days_to_departure': 15,
#   'class': 'business',
#   'price_usd': 553.31},
#  {'ticket_id': 'T812-0175',
#   'route': 'SFO-SEA',
#   'day': 'Mon',
#   'days_to_departure': 18,
#   'class': 'premium',
#   'price_usd': 227.83},
#  {'ticket_id': 'T812-0176',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 21,
#   'class': 'economy',
#   'price_usd': 204.32},
#  {'ticket_id': 'T812-0177',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 24,
#   'class': 'business',
#   'price_usd': 367.8},
#  {'ticket_id': 'T812-0178',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 27,
#   'class': 'premium',
#   'price_usd': 293.44},
#  {'ticket_id': 'T812-0179',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 30,
#   'class': 'economy',
#   'price_usd': 268.5},
#  {'ticket_id': 'T812-0181',
#   'route': 'DXB-SIN',
#   'day': 'Sun',
#   'days_to_departure': 36,
#   'class': 'premium',
#   'price_usd': 344.67},
#  {'ticket_id': 'T812-0182',
#   'route': 'MAD-ROM',
#   'day': 'Mon',
#   'days_to_departure': 39,
#   'class': 'economy',
#   'price_usd': 137.73},
#  {'ticket_id': 'T812-0183',
#   'route': 'NYC-LAX',
#   'day': 'Tue',
#   'days_to_departure': 42,
#   'class': 'business',
#   'price_usd': 352.64},
#  {'ticket_id': 'T812-0184',
#   'route': 'LHR-JFK',
#   'day': 'Wed',
#   'days_to_departure': 45,
#   'class': 'premium',
#   'price_usd': 389.43},
#  {'ticket_id': 'T812-0185',
#   'route': 'SFO-SEA',
#   'day': 'Thu',
#   'days_to_departure': 48,
#   'class': 'economy',
#   'price_usd': 126.62},
#  {'ticket_id': 'T812-0186',
#   'route': 'DXB-SIN',
#   'day': 'Fri',
#   'days_to_departure': 51,
#   'class': 'business',
#   'price_usd': 461.9},
#  {'ticket_id': 'T812-0187',
#   'route': 'MAD-ROM',
#   'day': 'Sat',
#   'days_to_departure': 54,
#   'class': 'premium',
#   'price_usd': 175.34},
#  {'ticket_id': 'T812-0188',
#   'route': 'NYC-LAX',
#   'day': 'Sun',
#   'days_to_departure': 57,
#   'class': 'economy',
#   'price_usd': 170.76},
#  {'ticket_id': 'T812-0189',
#   'route': 'LHR-JFK',
#   'day': 'Mon',
#   'days_to_departure': 60,
#   'class': 'business',
#   'price_usd': 471.46},
#  {'ticket_id': 'T812-0190',
#   'route': 'SFO-SEA',
#   'day': 'Tue',
#   'days_to_departure': 3,
#   'class': 'premium',
#   'price_usd': 264.41},
#  {'ticket_id': 'T812-0191',
#   'route': 'DXB-SIN',
#   'day': 'Wed',
#   'days_to_departure': 6,
#   'class': 'economy',
#   'price_usd': 326.33},
#  {'ticket_id': 'T812-0192',
#   'route': 'MAD-ROM',
#   'day': 'Thu',
#   'days_to_departure': 9,
#   'class': 'business',
#   'price_usd': 360.38},
#  {'ticket_id': 'T812-0193',
#   'route': 'NYC-LAX',
#   'day': 'Fri',
#   'days_to_departure': 12,
#   'class': 'premium',
#   'price_usd': 298.3},
#  {'ticket_id': 'T812-0194',
#   'route': 'LHR-JFK',
#   'day': 'Sat',
#   'days_to_departure': 15,
#   'class': 'economy',
#   'price_usd': 355.06},
#  {'ticket_id': 'T812-0195',
#   'route': 'SFO-SEA',
#   'day': 'Sun',
#   'days_to_departure': 18,
#   'class': 'business',
#   'price_usd': 358.25},
#  {'ticket_id': 'T812-0197',
#   'route': 'MAD-ROM',
#   'day': 'Tue',
#   'days_to_departure': 24,
#   'class': 'economy',
#   'price_usd': 163.42},
#  {'ticket_id': 'T812-0198',
#   'route': 'NYC-LAX',
#   'day': 'Wed',
#   'days_to_departure': 27,
#   'class': 'business',
#   'price_usd': 409.71},
#  {'ticket_id': 'T812-0199',
#   'route': 'LHR-JFK',
#   'day': 'Thu',
#   'days_to_departure': 30,
#   'class': 'premium',
#   'price_usd': 355.2},
#  {'ticket_id': 'T812-0200',
#   'route': 'SFO-SEA',
#   'day': 'Fri',
#   'days_to_departure': 33,
#   'class': 'economy',
#   'price_usd': 147.88},
#  {'ticket_id': 'T812-0201',
#   'route': 'DXB-SIN',
#   'day': 'Sat',
#   'days_to_departure': 36,
#   'class': 'business',
#   'price_usd': 476.84},
#  {'ticket_id': 'T812-0202',
#   'route': 'MAD-ROM',
#   'day': 'Sun',
#   'days_to_departure': 39,
#   'class': 'premium',
#   'price_usd': 247.78},
#  {'ticket_id': 'T812-0203',
#   'route': 'NYC-LAX',
#   'day': 'Mon',
#   'days_to_departure': 42,
#   'class': 'economy',
#   'price_usd': 228.71},
#  {'ticket_id': 'T812-0204',
#   'route': 'LHR-JFK',
#   'day': 'Tue',
#   'days_to_departure': 45,
#   'class': 'business',
#   'price_usd': 504.84},
#  {'ticket_id': 'T812-0205',
#   'route': 'SFO-SEA',
#   'day': 'Wed',
#   'days_to_departure': 48,
#   'class': 'premium',
#   'price_usd': 221.49},
#  {'ticket_id': 'T812-0206',
#   'route': 'DXB-SIN',
#   'day': 'Thu',
#   'days_to_departure': 51,
#   'class': 'economy',
#   'price_usd': 225.21},
#  {'ticket_id': 'T812-0207',
#   'route': 'MAD-ROM',
#   'day': 'Fri',
#   'days_to_departure': 54,
#   'class': 'business',
#   'price_usd': 302.78},
#  {'ticket_id': 'T812-0208',
#   'route': 'NYC-LAX',
#   'day': 'Sat',
#   'days_to_departure': 57,
#   'class': 'premium',
#   'price_usd': 297.56},
#  {'ticket_id': 'T812-0209',
#   'route': 'LHR-JFK',
#   'day': 'Sun',
#   'days_to_departure': 60,
#   'class': 'economy',
#   'price_usd': 258.88},
#  {'ticket_id': 'T812-0210',
#   'route': 'SFO-SEA',
#   'day': 'Mon',
#   'days_to_departure': 3,
#   'class': 'business',
#   'price_usd': 367.12},
#  {'ticket_id': 'T812-0211',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 6,
#   'class': 'premium',
#   'price_usd': 402.06},
#  {'ticket_id': 'T812-0212',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 9,
#   'class': 'economy',
#   'price_usd': 189.82},
#  {'ticket_id': 'T812-0213',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 12,
#   'class': 'business',
#   'price_usd': 505.66},
#  {'ticket_id': 'T812-0214',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 15,
#   'class': 'premium',
#   'price_usd': 389.73},
#  {'ticket_id': 'T812-0215',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 18,
#   'class': 'economy',
#   'price_usd': 152.92},
#  {'ticket_id': 'T812-0216',
#   'route': 'DXB-SIN',
#   'day': 'Sun',
#   'days_to_departure': 21,
#   'class': 'business',
#   'price_usd': 488.96},
#  {'ticket_id': 'T812-0217',
#   'route': 'MAD-ROM',
#   'day': 'Mon',
#   'days_to_departure': 24,
#   'class': 'premium',
#   'price_usd': 227.08},
#  {'ticket_id': 'T812-0218',
#   'route': 'NYC-LAX',
#   'day': 'Tue',
#   'days_to_departure': 27,
#   'class': 'economy',
#   'price_usd': 214.9},
#  {'ticket_id': 'T812-0219',
#   'route': 'LHR-JFK',
#   'day': 'Wed',
#   'days_to_departure': 30,
#   'class': 'business',
#   'price_usd': 500.87},
#  {'ticket_id': 'T812-0220',
#   'route': 'SFO-SEA',
#   'day': 'Thu',
#   'days_to_departure': 33,
#   'class': 'premium',
#   'price_usd': 235.57},
#  {'ticket_id': 'T812-0221',
#   'route': 'DXB-SIN',
#   'day': 'Fri',
#   'days_to_departure': 36,
#   'class': 'economy',
#   'price_usd': 238.34},
#  {'ticket_id': 'T812-0222',
#   'route': 'MAD-ROM',
#   'day': 'Sat',
#   'days_to_departure': 39,
#   'class': 'business',
#   'price_usd': 366.05},
#  {'ticket_id': 'T812-0223',
#   'route': 'NYC-LAX',
#   'day': 'Sun',
#   'days_to_departure': 42,
#   'class': 'premium',
#   'price_usd': 287.52},
#  {'ticket_id': 'T812-0226',
#   'route': 'DXB-SIN',
#   'day': 'Wed',
#   'days_to_departure': 51,
#   'class': 'premium',
#   'price_usd': 309.98},
#  {'ticket_id': 'T812-0227',
#   'route': 'MAD-ROM',
#   'day': 'Thu',
#   'days_to_departure': 54,
#   'class': 'economy',
#   'price_usd': 130.38},
#  {'ticket_id': 'T812-0228',
#   'route': 'NYC-LAX',
#   'day': 'Fri',
#   'days_to_departure': 57,
#   'class': 'business',
#   'price_usd': 402.11},
#  {'ticket_id': 'T812-0229',
#   'route': 'LHR-JFK',
#   'day': 'Sat',
#   'days_to_departure': 60,
#   'class': 'premium',
#   'price_usd': 318.38},
#  {'ticket_id': 'T812-0230',
#   'route': 'SFO-SEA',
#   'day': 'Sun',
#   'days_to_departure': 3,
#   'class': 'economy',
#   'price_usd': 212.05},
#  {'ticket_id': 'T812-0231',
#   'route': 'DXB-SIN',
#   'day': 'Mon',
#   'days_to_departure': 6,
#   'class': 'business',
#   'price_usd': 492.93},
#  {'ticket_id': 'T812-0232',
#   'route': 'MAD-ROM',
#   'day': 'Tue',
#   'days_to_departure': 9,
#   'class': 'premium',
#   'price_usd': 234.91},
#  {'ticket_id': 'T812-0233',
#   'route': 'NYC-LAX',
#   'day': 'Wed',
#   'days_to_departure': 12,
#   'class': 'economy',
#   'price_usd': 269.64},
#  {'ticket_id': 'T812-0234',
#   'route': 'LHR-JFK',
#   'day': 'Thu',
#   'days_to_departure': 15,
#   'class': 'business',
#   'price_usd': 493.97},
#  {'ticket_id': 'T812-0235',
#   'route': 'SFO-SEA',
#   'day': 'Fri',
#   'days_to_departure': 18,
#   'class': 'premium',
#   'price_usd': 215.22},
#  {'ticket_id': 'T812-0236',
#   'route': 'DXB-SIN',
#   'day': 'Sat',
#   'days_to_departure': 21,
#   'class': 'economy',
#   'price_usd': 295.38},
#  {'ticket_id': 'T812-0237',
#   'route': 'MAD-ROM',
#   'day': 'Sun',
#   'days_to_departure': 24,
#   'class': 'business',
#   'price_usd': 357.8},
#  {'ticket_id': 'T812-0238',
#   'route': 'NYC-LAX',
#   'day': 'Mon',
#   'days_to_departure': 27,
#   'class': 'premium',
#   'price_usd': 269.98},
#  {'ticket_id': 'T812-0239',
#   'route': 'LHR-JFK',
#   'day': 'Tue',
#   'days_to_departure': 30,
#   'class': 'economy',
#   'price_usd': 310.61},
#  {'ticket_id': 'T812-0240',
#   'route': 'SFO-SEA',
#   'day': 'Wed',
#   'days_to_departure': 33,
#   'class': 'business',
#   'price_usd': 350.98},
#  {'ticket_id': 'T812-0241',
#   'route': 'DXB-SIN',
#   'day': 'Thu',
#   'days_to_departure': 36,
#   'class': 'premium',
#   'price_usd': 306.65},
#  {'ticket_id': 'T812-0242',
#   'route': 'MAD-ROM',
#   'day': 'Fri',
#   'days_to_departure': 39,
#   'class': 'economy',
#   'price_usd': 119.2},
#  {'ticket_id': 'T812-0243',
#   'route': 'NYC-LAX',
#   'day': 'Sat',
#   'days_to_departure': 42,
#   'class': 'business',
#   'price_usd': 359.86},
#  {'ticket_id': 'T812-0244',
#   'route': 'LHR-JFK',
#   'day': 'Sun',
#   'days_to_departure': 45,
#   'class': 'premium',
#   'price_usd': 336.01},
#  {'ticket_id': 'T812-0245',
#   'route': 'SFO-SEA',
#   'day': 'Mon',
#   'days_to_departure': 48,
#   'class': 'economy',
#   'price_usd': 124.85},
#  {'ticket_id': 'T812-0246',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 51,
#   'class': 'business',
#   'price_usd': 414.87},
#  {'ticket_id': 'T812-0247',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 54,
#   'class': 'premium',
#   'price_usd': 202.71},
#  {'ticket_id': 'T812-0248',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 57,
#   'class': 'economy',
#   'price_usd': 181.67},
#  {'ticket_id': 'T812-0249',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 60,
#   'class': 'business',
#   'price_usd': 440.5},
#  {'ticket_id': 'T812-0250',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 3,
#   'class': 'premium',
#   'price_usd': 265.01},
#  {'ticket_id': 'T812-0251',
#   'route': 'DXB-SIN',
#   'day': 'Sun',
#   'days_to_departure': 6,
#   'class': 'economy',
#   'price_usd': 303.17},
#  {'ticket_id': 'T812-0253',
#   'route': 'NYC-LAX',
#   'day': 'Tue',
#   'days_to_departure': 12,
#   'class': 'premium',
#   'price_usd': 323.91},
#  {'ticket_id': 'T812-0254',
#   'route': 'LHR-JFK',
#   'day': 'Wed',
#   'days_to_departure': 15,
#   'class': 'economy',
#   'price_usd': 296.99},
#  {'ticket_id': 'T812-0255',
#   'route': 'SFO-SEA',
#   'day': 'Thu',
#   'days_to_departure': 18,
#   'class': 'business',
#   'price_usd': 364.16},
#  {'ticket_id': 'T812-0256',
#   'route': 'DXB-SIN',
#   'day': 'Fri',
#   'days_to_departure': 21,
#   'class': 'premium',
#   'price_usd': 330.17},
#  {'ticket_id': 'T812-0257',
#   'route': 'MAD-ROM',
#   'day': 'Sat',
#   'days_to_departure': 24,
#   'class': 'economy',
#   'price_usd': 171.28},
#  {'ticket_id': 'T812-0258',
#   'route': 'NYC-LAX',
#   'day': 'Sun',
#   'days_to_departure': 27,
#   'class': 'business',
#   'price_usd': 433.11},
#  {'ticket_id': 'T812-0259',
#   'route': 'LHR-JFK',
#   'day': 'Mon',
#   'days_to_departure': 30,
#   'class': 'premium',
#   'price_usd': 368.19},
#  {'ticket_id': 'T812-0260',
#   'route': 'SFO-SEA',
#   'day': 'Tue',
#   'days_to_departure': 33,
#   'class': 'economy',
#   'price_usd': 136.86},
#  {'ticket_id': 'T812-0261',
#   'route': 'DXB-SIN',
#   'day': 'Wed',
#   'days_to_departure': 36,
#   'class': 'business',
#   'price_usd': 476.92},
#  {'ticket_id': 'T812-0262',
#   'route': 'MAD-ROM',
#   'day': 'Thu',
#   'days_to_departure': 39,
#   'class': 'premium',
#   'price_usd': 190.75},
#  {'ticket_id': 'T812-0263',
#   'route': 'NYC-LAX',
#   'day': 'Fri',
#   'days_to_departure': 42,
#   'class': 'economy',
#   'price_usd': 207.49},
#  {'ticket_id': 'T812-0264',
#   'route': 'LHR-JFK',
#   'day': 'Sat',
#   'days_to_departure': 45,
#   'class': 'business',
#   'price_usd': 454.03},
#  {'ticket_id': 'T812-0265',
#   'route': 'SFO-SEA',
#   'day': 'Sun',
#   'days_to_departure': 48,
#   'class': 'premium',
#   'price_usd': 158.48},
#  {'ticket_id': 'T812-0266',
#   'route': 'DXB-SIN',
#   'day': 'Mon',
#   'days_to_departure': 51,
#   'class': 'economy',
#   'price_usd': 222.88},
#  {'ticket_id': 'T812-0267',
#   'route': 'MAD-ROM',
#   'day': 'Tue',
#   'days_to_departure': 54,
#   'class': 'business',
#   'price_usd': 372.84},
#  {'ticket_id': 'T812-0268',
#   'route': 'NYC-LAX',
#   'day': 'Wed',
#   'days_to_departure': 57,
#   'class': 'premium',
#   'price_usd': 255.78},
#  {'ticket_id': 'T812-0269',
#   'route': 'LHR-JFK',
#   'day': 'Thu',
#   'days_to_departure': 60,
#   'class': 'economy',
#   'price_usd': 249.2},
#  {'ticket_id': 'T812-0271',
#   'route': 'DXB-SIN',
#   'day': 'Sat',
#   'days_to_departure': 6,
#   'class': 'premium',
#   'price_usd': 350.24},
#  {'ticket_id': 'T812-0272',
#   'route': 'MAD-ROM',
#   'day': 'Sun',
#   'days_to_departure': 9,
#   'class': 'economy',
#   'price_usd': 176.51},
#  {'ticket_id': 'T812-0273',
#   'route': 'NYC-LAX',
#   'day': 'Mon',
#   'days_to_departure': 12,
#   'class': 'business',
#   'price_usd': 476.02},
#  {'ticket_id': 'T812-0274',
#   'route': 'LHR-JFK',
#   'day': 'Tue',
#   'days_to_departure': 15,
#   'class': 'premium',
#   'price_usd': 423.37},
#  {'ticket_id': 'T812-0275',
#   'route': 'SFO-SEA',
#   'day': 'Wed',
#   'days_to_departure': 18,
#   'class': 'economy',
#   'price_usd': 100.72},
#  {'ticket_id': 'T812-0276',
#   'route': 'DXB-SIN',
#   'day': 'Thu',
#   'days_to_departure': 21,
#   'class': 'business',
#   'price_usd': 527.79},
#  {'ticket_id': 'T812-0277',
#   'route': 'MAD-ROM',
#   'day': 'Fri',
#   'days_to_departure': 24,
#   'class': 'premium',
#   'price_usd': 254.23},
#  {'ticket_id': 'T812-0278',
#   'route': 'NYC-LAX',
#   'day': 'Sat',
#   'days_to_departure': 27,
#   'class': 'economy',
#   'price_usd': 232.98},
#  {'ticket_id': 'T812-0279',
#   'route': 'LHR-JFK',
#   'day': 'Sun',
#   'days_to_departure': 30,
#   'class': 'business',
#   'price_usd': 482.86},
#  {'ticket_id': 'T812-0281',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 36,
#   'class': 'economy',
#   'price_usd': 273.56},
#  {'ticket_id': 'T812-0282',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 39,
#   'class': 'business',
#   'price_usd': 370.84},
#  {'ticket_id': 'T812-0283',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 42,
#   'class': 'premium',
#   'price_usd': 323.95},
#  {'ticket_id': 'T812-0284',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 45,
#   'class': 'economy',
#   'price_usd': 276.56},
#  {'ticket_id': 'T812-0285',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 48,
#   'class': 'business',
#   'price_usd': 371.88},
#  {'ticket_id': 'T812-0286',
#   'route': 'DXB-SIN',
#   'day': 'Sun',
#   'days_to_departure': 51,
#   'class': 'premium',
#   'price_usd': 341.07},
#  {'ticket_id': 'T812-0287',
#   'route': 'MAD-ROM',
#   'day': 'Mon',
#   'days_to_departure': 54,
#   'class': 'economy',
#   'price_usd': 136.38},
#  {'ticket_id': 'T812-0288',
#   'route': 'NYC-LAX',
#   'day': 'Tue',
#   'days_to_departure': 57,
#   'class': 'business',
#   'price_usd': 384.95},
#  {'ticket_id': 'T812-0289',
#   'route': 'LHR-JFK',
#   'day': 'Wed',
#   'days_to_departure': 60,
#   'class': 'premium',
#   'price_usd': 384.64},
#  {'ticket_id': 'T812-0290',
#   'route': 'SFO-SEA',
#   'day': 'Thu',
#   'days_to_departure': 3,
#   'class': 'economy',
#   'price_usd': 173.13},
#  {'ticket_id': 'T812-0291',
#   'route': 'DXB-SIN',
#   'day': 'Fri',
#   'days_to_departure': 6,
#   'class': 'business',
#   'price_usd': 498.59},
#  {'ticket_id': 'T812-0292',
#   'route': 'MAD-ROM',
#   'day': 'Sat',
#   'days_to_departure': 9,
#   'class': 'premium',
#   'price_usd': 272.36},
#  {'ticket_id': 'T812-0293',
#   'route': 'NYC-LAX',
#   'day': 'Sun',
#   'days_to_departure': 12,
#   'class': 'economy',
#   'price_usd': 218.91},
#  {'ticket_id': 'T812-0294',
#   'route': 'LHR-JFK',
#   'day': 'Mon',
#   'days_to_departure': 15,
#   'class': 'business',
#   'price_usd': 557.76},
#  {'ticket_id': 'T812-0295',
#   'route': 'SFO-SEA',
#   'day': 'Tue',
#   'days_to_departure': 18,
#   'class': 'premium',
#   'price_usd': 233.7},
#  {'ticket_id': 'T812-0296',
#   'route': 'DXB-SIN',
#   'day': 'Wed',
#   'days_to_departure': 21,
#   'class': 'economy',
#   'price_usd': 238.01},
#  {'ticket_id': 'T812-0297',
#   'route': 'MAD-ROM',
#   'day': 'Thu',
#   'days_to_departure': 24,
#   'class': 'business',
#   'price_usd': 407.67},
#  {'ticket_id': 'T812-0298',
#   'route': 'NYC-LAX',
#   'day': 'Fri',
#   'days_to_departure': 27,
#   'class': 'premium',
#   'price_usd': 266.2},
#  {'ticket_id': 'T812-0299',
#   'route': 'LHR-JFK',
#   'day': 'Sat',
#   'days_to_departure': 30,
#   'class': 'economy',
#   'price_usd': 300.36},
#  {'ticket_id': 'T812-0300',
#   'route': 'SFO-SEA',
#   'day': 'Sun',
#   'days_to_departure': 33,
#   'class': 'business',
#   'price_usd': 372.74},
#  {'ticket_id': 'T812-0301',
#   'route': 'DXB-SIN',
#   'day': 'Mon',
#   'days_to_departure': 36,
#   'class': 'premium',
#   'price_usd': 326.65},
#  {'ticket_id': 'T812-0302',
#   'route': 'MAD-ROM',
#   'day': 'Tue',
#   'days_to_departure': 39,
#   'class': 'economy',
#   'price_usd': 93.76},
#  {'ticket_id': 'T812-0303',
#   'route': 'NYC-LAX',
#   'day': 'Wed',
#   'days_to_departure': 42,
#   'class': 'business',
#   'price_usd': 381.5},
#  {'ticket_id': 'T812-0304',
#   'route': 'LHR-JFK',
#   'day': 'Thu',
#   'days_to_departure': 45,
#   'class': 'premium',
#   'price_usd': 381.77},
#  {'ticket_id': 'T812-0305',
#   'route': 'SFO-SEA',
#   'day': 'Fri',
#   'days_to_departure': 48,
#   'class': 'economy',
#   'price_usd': 139.18},
#  {'ticket_id': 'T812-0306',
#   'route': 'DXB-SIN',
#   'day': 'Sat',
#   'days_to_departure': 51,
#   'class': 'business',
#   'price_usd': 444.23},
#  {'ticket_id': 'T812-0307',
#   'route': 'MAD-ROM',
#   'day': 'Sun',
#   'days_to_departure': 54,
#   'class': 'premium',
#   'price_usd': 172.7},
#  {'ticket_id': 'T812-0309',
#   'route': 'LHR-JFK',
#   'day': 'Tue',
#   'days_to_departure': 60,
#   'class': 'business',
#   'price_usd': 508.31},
#  {'ticket_id': 'T812-0310',
#   'route': 'SFO-SEA',
#   'day': 'Wed',
#   'days_to_departure': 3,
#   'class': 'premium',
#   'price_usd': 264.34},
#  {'ticket_id': 'T812-0311',
#   'route': 'DXB-SIN',
#   'day': 'Thu',
#   'days_to_departure': 6,
#   'class': 'economy',
#   'price_usd': 262.73},
#  {'ticket_id': 'T812-0312',
#   'route': 'MAD-ROM',
#   'day': 'Fri',
#   'days_to_departure': 9,
#   'class': 'business',
#   'price_usd': 399.48},
#  {'ticket_id': 'T812-0313',
#   'route': 'NYC-LAX',
#   'day': 'Sat',
#   'days_to_departure': 12,
#   'class': 'premium',
#   'price_usd': 364.25},
#  {'ticket_id': 'T812-0314',
#   'route': 'LHR-JFK',
#   'day': 'Sun',
#   'days_to_departure': 15,
#   'class': 'economy',
#   'price_usd': 320.73},
#  {'ticket_id': 'T812-0316',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 21,
#   'class': 'premium',
#   'price_usd': 348.95},
#  {'ticket_id': 'T812-0317',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 24,
#   'class': 'economy',
#   'price_usd': 184.04},
#  {'ticket_id': 'T812-0318',
#   'route': 'NYC-LAX',
#   'day': 'Thu',
#   'days_to_departure': 27,
#   'class': 'business',
#   'price_usd': 487.86},
#  {'ticket_id': 'T812-0319',
#   'route': 'LHR-JFK',
#   'day': 'Fri',
#   'days_to_departure': 30,
#   'class': 'premium',
#   'price_usd': 353.16},
#  {'ticket_id': 'T812-0320',
#   'route': 'SFO-SEA',
#   'day': 'Sat',
#   'days_to_departure': 33,
#   'class': 'economy',
#   'price_usd': 142.45}]

# %%
len(tickets)
# Out:
# 320

# %%
len(cleaned_records)
# Out:
# 302

# %%
if all( isinstance(p['price_usd'], (int, float)) and p['price_usd'] >0 and p['class'] == p['class'].lower() 
        for p in cleaned_records):
  print('All are valid')

else:
    print("Some records are invalid")
# Out:
# All are valid

# %%
cleaned_records[:2]
# Out:
# [{'ticket_id': 'T812-0001',
#   'route': 'DXB-SIN',
#   'day': 'Tue',
#   'days_to_departure': 36,
#   'class': 'premium',
#   'price_usd': 298.26},
#  {'ticket_id': 'T812-0002',
#   'route': 'MAD-ROM',
#   'day': 'Wed',
#   'days_to_departure': 39,
#   'class': 'economy',
#   'price_usd': 156.11}]

# %% [markdown]
# # Task 3: Convert to NumPy for analysis
# Create NumPy arrays for prices and days. Compute mean and standard deviation of prices. Compute total revenue per day and ticket counts per day using vectorized operations (no loops). Validate daily totals sum to overall total revenue.

# %%
array_prices = np.array([ a['price_usd'] for a in cleaned_records])
array_prices
# Out:
# array([298.26, 156.11, 429.67, 413.07, 117.02, 450.43, 171.18, 145.16,
#        429.25, 315.81, 311.3 , 407.13, 302.  , 343.47, 362.25, 402.66,
#        146.76, 473.9 , 427.17, 139.61, 471.15, 249.56, 174.63, 544.85,
#        176.67, 216.58, 341.88, 310.02, 417.53, 348.68, 210.88, 491.68,
#        445.63, 200.72, 472.81, 220.67, 236.22, 560.76, 234.28, 187.23,
#        347.76, 308.51, 263.  , 314.45, 139.73, 345.12, 328.21, 178.7 ,
#        482.02, 238.95, 204.02, 556.98, 264.94, 366.37, 314.7 , 292.71,
#        324.5 , 355.56, 180.93, 378.26, 395.66,  85.41, 431.78, 229.97,
#        186.61, 432.11, 223.6 , 312.27, 446.5 , 300.48, 364.66, 362.79,
#        343.44, 186.01, 430.29, 386.03, 136.61, 500.18, 211.57, 218.34,
#        211.49, 227.44, 387.08, 249.66, 220.19, 335.26, 189.26, 490.77,
#        382.06, 126.82, 456.71, 224.68, 226.47, 518.32, 194.72, 230.49,
#        341.42, 294.66, 255.72, 332.85, 289.82, 109.89, 388.8 , 358.67,
#        173.62, 459.7 , 223.68, 518.5 , 254.44, 290.17, 371.21, 266.67,
#        278.07, 356.17, 318.81, 137.98, 406.24, 359.92, 118.44, 396.23,
#        209.23, 199.12, 474.04, 250.76, 282.03, 402.52, 365.67, 289.61,
#        381.52, 189.31, 428.25, 312.07, 451.96, 249.76, 191.29, 522.45,
#        210.01, 237.49, 315.87, 288.89, 236.21, 396.09, 381.55, 158.38,
#        495.17, 382.47, 121.11, 493.94, 245.56, 241.92, 437.3 , 192.43,
#        267.73, 365.49, 292.9 , 264.66, 347.98, 257.28,  97.02, 358.17,
#        187.34, 540.53, 275.26, 227.97, 553.31, 227.83, 204.32, 367.8 ,
#        293.44, 268.5 , 344.67, 137.73, 352.64, 389.43, 126.62, 461.9 ,
#        175.34, 170.76, 471.46, 264.41, 326.33, 360.38, 298.3 , 355.06,
#        358.25, 163.42, 409.71, 355.2 , 147.88, 476.84, 247.78, 228.71,
#        504.84, 221.49, 225.21, 302.78, 297.56, 258.88, 367.12, 402.06,
#        189.82, 505.66, 389.73, 152.92, 488.96, 227.08, 214.9 , 500.87,
#        235.57, 238.34, 366.05, 287.52, 309.98, 130.38, 402.11, 318.38,
#        212.05, 492.93, 234.91, 269.64, 493.97, 215.22, 295.38, 357.8 ,
#        269.98, 310.61, 350.98, 306.65, 119.2 , 359.86, 336.01, 124.85,
#        414.87, 202.71, 181.67, 440.5 , 265.01, 303.17, 323.91, 296.99,
#        364.16, 330.17, 171.28, 433.11, 368.19, 136.86, 476.92, 190.75,
#        207.49, 454.03, 158.48, 222.88, 372.84, 255.78, 249.2 , 350.24,
#        176.51, 476.02, 423.37, 100.72, 527.79, 254.23, 232.98, 482.86,
#        273.56, 370.84, 323.95, 276.56, 371.88, 341.07, 136.38, 384.95,
#        384.64, 173.13, 498.59, 272.36, 218.91, 557.76, 233.7 , 238.01,
#        407.67, 266.2 , 300.36, 372.74, 326.65,  93.76, 381.5 , 381.77,
#        139.18, 444.23, 172.7 , 508.31, 264.34, 262.73, 399.48, 364.25,
#        320.73, 348.95, 184.04, 487.86, 353.16, 142.45])

# %%
array_days = np.array([ c['day'] for c in cleaned_records])
array_days
# Out:
# array(['Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed',
#        'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun',
#        'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed',
#        'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Tue',
#        'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Tue',
#        'Wed', 'Thu', 'Fri', 'Sat', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Tue', 'Wed',
#        'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tue', 'Thu', 'Fri', 'Sat', 'Sun', 'Tue', 'Wed', 'Thu',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Tue', 'Wed', 'Thu',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sun',
#        'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue',
#        'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Tue', 'Wed', 'Thu', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue',
#        'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Wed', 'Thu', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed',
#        'Thu', 'Fri', 'Sat', 'Sun', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tue', 'Wed', 'Thu', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu',
#        'Fri', 'Sat', 'Sun', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue',
#        'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu',
#        'Fri', 'Sat', 'Sun', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun',
#        'Tue', 'Wed', 'Thu', 'Fri', 'Sat'], dtype='<U3')

# %%
mean_price =np.mean(array_prices)
mean_price
# Out:
# np.float64(308.82480132450337)

# %%
std_price = np.std(array_prices)
std_price
# Out:
# np.float64(111.69676125398355)

# %%
unique_days, day_indices = np.unique(array_days, return_inverse = True)
unique_days
# Out:
# array(['Fri', 'Mon', 'Sat', 'Sun', 'Thu', 'Tue', 'Wed'], dtype='<U3')

# %%
total_revenue_per_day = np.bincount(day_indices, weights = array_prices)
total_revenue_per_day
# Out:
# array([14076.09, 10186.55, 13751.09, 13309.84, 14280.82, 13870.25,
#        13790.45])

# %%
matched_day = dict(zip(unique_days, total_revenue_per_day))
matched_day
# Out:
# {np.str_('Fri'): np.float64(14076.089999999998),
#  np.str_('Mon'): np.float64(10186.55),
#  np.str_('Sat'): np.float64(13751.09),
#  np.str_('Sun'): np.float64(13309.839999999998),
#  np.str_('Thu'): np.float64(14280.82),
#  np.str_('Tue'): np.float64(13870.250000000002),
#  np.str_('Wed'): np.float64(13790.449999999999)}

# %%
day_indices
# Out:
# array([5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5,
#        6, 4, 0, 2, 3, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 0,
#        2, 3, 1, 5, 6, 4, 0, 2, 3, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3,
#        1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 5, 6, 4, 0, 2, 1, 5, 6,
#        4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 5, 6, 4, 0,
#        2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 4, 0, 2, 3,
#        5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5,
#        6, 4, 0, 2, 3, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 3, 1, 5, 6, 4, 0,
#        2, 3, 1, 5, 6, 4, 0, 2, 3, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3,
#        1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 6, 4, 0, 2, 3, 1, 5, 6,
#        4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 5, 6, 4, 0,
#        2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 2, 3, 1, 5, 6, 4, 0, 2, 3,
#        5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5,
#        6, 4, 0, 2, 3, 5, 6, 4, 0, 2, 3, 5, 6, 4, 0, 2])

# %%
ticket_counts = np.bincount(day_indices)
ticket_counts
# Out:
# array([45, 33, 45, 44, 45, 45, 45])

# %%
result = dict(zip(unique_days, ticket_counts))
result
# Out:
# {np.str_('Fri'): np.int64(45),
#  np.str_('Mon'): np.int64(33),
#  np.str_('Sat'): np.int64(45),
#  np.str_('Sun'): np.int64(44),
#  np.str_('Thu'): np.int64(45),
#  np.str_('Tue'): np.int64(45),
#  np.str_('Wed'): np.int64(45)}

# %%
for day,value in matched_day.items():
    print(str(day),':', round(value,2))
# Out:
# Fri : 14076.09
# Mon : 10186.55
# Sat : 13751.09
# Sun : 13309.84
# Thu : 14280.82
# Tue : 13870.25
# Wed : 13790.45

# %%
overall_revenue = np.sum(array_prices)
overall_revenue
# Out:
# np.float64(93265.09000000001)

# %%
sum_total_revenue_per_day= np.sum(total_revenue_per_day)
sum_total_revenue_per_day
# Out:
# np.float64(93265.08999999998)

# %%
assert np.isclose(overall_revenue, sum_total_revenue_per_day), "They are not equal"
print("Both are equal")
# Out:
# Both are equal

# %% [markdown]
# # Task 4: Identify high-price tickets
# Define high-price tickets as above the 90th percentile of prices. Compute threshold and count. Verify all selected prices are >= threshold.

# %%
threshold = np.percentile(array_prices, 90)
threshold
# Out:
# np.float64(473.791)

# %%
high_price_ticket = array_prices >= threshold 
high_price_ticket
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#         True, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False,  True, False, False, False, False, False,
#        False, False, False,  True, False, False,  True, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False,  True, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False,  True,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False,  True, False, False])

# %%
high_price_tickets = array_prices[high_price_ticket]
high_price_tickets
# Out:
# array([473.9 , 544.85, 491.68, 560.76, 482.02, 556.98, 500.18, 490.77,
#        518.32, 518.5 , 474.04, 522.45, 495.17, 493.94, 540.53, 553.31,
#        476.84, 504.84, 505.66, 488.96, 500.87, 492.93, 493.97, 476.92,
#        476.02, 527.79, 482.86, 498.59, 557.76, 508.31, 487.86])

# %%
count = np.sum(high_price_ticket)
count
# Out:
# np.int64(31)

# %%
t =np.all(high_price_tickets >= threshold)
print(t)
# Out:
# True

# %% [markdown]
# # Task 5: Produce a final report
# Create a report dictionary with keys:
#
# total_tickets
# cleaned_tickets
# mean_price
# std_price
# daily_totals
# high_price_count
# Print a readable report and include at least one explicit validation statement.

# %%
report = {'total_tickets':len(tickets),
          'cleaned_tickets':len(cleaned_records),
          'mean_price': mean_price,
          'std_price': std_price,
          'daily_totals': {str(day): round(float(value),2) for day, value in matched_day.items()},
          'high_price_count':count
         }

# %%
report
# Out:
# {'total_tickets': 320,
#  'cleaned_tickets': 302,
#  'mean_price': np.float64(308.82480132450337),
#  'std_price': np.float64(111.69676125398355),
#  'daily_totals': {'Fri': 14076.09,
#   'Mon': 10186.55,
#   'Sat': 13751.09,
#   'Sun': 13309.84,
#   'Thu': 14280.82,
#   'Tue': 13870.25,
#   'Wed': 13790.45},
#  'high_price_count': np.int64(31)}

# %%
string_report= f"""

THIS IS READIBLE REPORT

Total Tickets : {report['total_tickets']}
Cleaned Tickets : { report['cleaned_tickets']}
Price Mean : {report['mean_price']}
Price Std : { report['std_price']}
Daily Totals : { report['daily_totals']}
High Price Count : {report['high_price_count']}
"""

print(string_report)
# Out:
# THIS IS READIBLE REPORT
#
# Total Tickets : 320
# Cleaned Tickets : 302
# Price Mean : 308.82480132450337
# Price Std : 111.69676125398355
# Daily Totals : {'Fri': 14076.09, 'Mon': 10186.55, 'Sat': 13751.09, 'Sun': 13309.84, 'Thu': 14280.82, 'Tue': 13870.25, 'Wed': 13790.45}
# High Price Count : 31
